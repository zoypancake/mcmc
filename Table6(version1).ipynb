# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
from tools import *
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
from scipy.stats import multivariate_normal
from scipy.misc import derivative
from scipy.linalg import fractional_matrix_power
from scipy.stats import wishart
import sys
import time

# %%
def logistic_inverse(x):
    return(-np.log(1/x-1))
#     return scipy.stats.logistic.ppf(x)

def logistic_diff(x):
    return(abs(1/x+1/(1-x)))
#     return abs(derivative(logistic_inverse,x,dx=1e-6))

def t_inverse(x):
    return scipy.stats.t.ppf(x,df=2)

def t_diff(x):
    return abs(derivative(t_inverse,x,dx=1e-6))

def exp_inverse(x):
    return(-np.log(x))

def exp_diff(x):
    return(abs(1/x))

def logtargetpdf(x, target, kernel):
    lnp = 0.0
    if (target == 'Exp'):
        if 'Trans' in kernel:
            lnp = 0 if 0<=x<=1 else -500
        else:
            lnp = -x if (x>=0) else -500
    elif (target == 'Folded_Gaussian'):
        if 'Trans' in kernel:
            x_inv = exp_inverse(x)
            lnp = -x_inv*x_inv/2 + np.log(exp_diff(x)) if 0<=x<=1 else -500
        else:
            lnp = -x*x/2 if (x>=0) else -500
    elif (target == 'N01_T2'):
        if 'Trans' in kernel:
            x_inv = t_inverse(x)
            lnp = -x_inv*x_inv/2 + np.log(t_diff(x)) if 0<=x<=1 else -500
        else:
            lnp = -x*x/2
    elif (target == 'N01_Logistic'):
        if 'Trans' in kernel:
            x_inv = logistic_inverse(x)
            lnp = -x_inv*x_inv/2 + np.log(logistic_diff(x)) if 0<=x<=1 else -500
        else:
            lnp = -x*x/2
    return (lnp)

# %%
#MCMC sampling implementation
# np.random.seed(121)
begin_total = time.time()
nround = int(10e5)
burnin = int(10e4)
size = len(range(-burnin,nround))
sigmaset = [0.1, 0.3, 0.5, 0.7, 0.8, 0.9, 1, 1.1, 1.3, 1.5, 1.7,
                    1.8, 1.9, 2, 2.1, 2.2, 2.3, 2.4, 2.5, 2.6, 2.8,
                    3.0, 3.2, 3.5, 4, 4.5, 5, 6, 7, 8]
kernelset = ['Uniform','TransUniform','TransBactrian','TransStrawHat']
targetset = ['Exp','Folded_Gaussian','N01_Logistic']

sample_Normal = np.random.normal(size = size)
sample_Uniform = np.random.uniform(low=-np.sqrt(3), high=np.sqrt(3), size=size)
sample_bactrian = random_bactrian(size = size)
sample_strawhat = random_strawhat(size=size)
target_result = {}

for target in targetset:
    eff_kernel = {}; Pjump_kernel = {}; Exx2_kernel = {}; Rho_kernel={}; Sample_kernel={}
    for kernel in kernelset:
        Eff = []; Pjump = []; Exx2=[]; Rho=[]; Sample=[]
        for sigma in sigmaset:
            begin_loop = time.time()
            exx2 = 0; accept = 0; 
            x = abs(np.random.random() - 0.5)
            y = np.zeros(nround)
            for j in range(-burnin,nround):
                if (j==0):
                    accept = 0;
                if 'Gaussian' in kernel:
                    xnew = x + sample_Normal[j+burnin] * sigma
                elif 'Uniform' in kernel:
                    xnew = x + sample_Uniform[j+burnin] *sigma
                elif 'Bactrian' in kernel:
                    xnew = x + sample_bactrian[j+burnin] *sigma
                elif 'StrawHat' in kernel:
                    xnew = x + sample_strawhat[j+burnin] *sigma

                
                if (('Trans' in kernel) & (not (0 <= xnew <= 1))):
                    xnew = reflect(xnew, xL=0, xU=1)
                if (((target=='Exp') | (target=='Folded_Gaussian')) & ('Trans' not in kernel)) & (xnew<0):
                    xnew = -xnew

                pi_dif = logtargetpdf(xnew,target,kernel) - logtargetpdf(x,target,kernel)
                if ((pi_dif>0) | (np.exp(pi_dif)>np.random.random())):
                    x = xnew
                    accept += 1
                if (j>=0):
                    if (((target=='Exp')|(target=='Folded_Gaussian')) & ('Trans' in kernel)):
                        y[j] = exp_inverse(x)
                    elif ((target=='N01_Logistic') & ('Trans' in kernel)):
                        y[j] = logistic_inverse(x)
                    else:
                        y[j] = x
            eff = (Eff_IntegratedCorrelationTime(y))
            rho = [rho_k(y,i) for i in range(1,11)]
            exx2 = sum(np.square(y[1:] - y[:-1]))
            Eff.append(eff)
            Pjump.append(accept/nround)
            Exx2.append(exx2/nround)
            Rho.append(rho)
            Sample.append(y.copy())
            print ('Target:',target,'|Kernel:',kernel,'|sigma:',sigma,'|eff:',round(eff,4), '|Pjump:', round(accept/nround,4), '|Exx2:', round(exx2/nround,4),
                   '|rho1:', round(rho[0],4), '|rho2:', round(rho[1],4) ,'|Time:',round((time.time()-begin_loop),2),sep='')
        eff_kernel[kernel] = Eff
        Pjump_kernel[kernel] = Pjump
        Exx2_kernel[kernel] = Exx2
        Rho_kernel[kernel] = Rho
        Sample_kernel[kernel] = Sample
    target_result[target] = [eff_kernel,Pjump_kernel,Exx2_kernel,Rho_kernel,Sample_kernel]
print('总共用时: %f'% (time.time()-begin_total))
# Out:
# Target:Exp|Kernel:Uniform|sigma:0.1|eff:0.0013|Pjump:0.9581|Exx2:0.009|rho1:0.9955|rho2:0.9913|Time:13.14
# Target:Exp|Kernel:Uniform|sigma:0.3|eff:0.0091|Pjump:0.8809|Exx2:0.0654|rho1:0.9669|rho2:0.938|Time:9.01
# Target:Exp|Kernel:Uniform|sigma:0.5|eff:0.0238|Pjump:0.812|Exx2:0.1475|rho1:0.9252|rho2:0.8641|Time:7.56
# Target:Exp|Kernel:Uniform|sigma:0.7|eff:0.0407|Pjump:0.7493|Exx2:0.2356|rho1:0.8811|rho2:0.7889|Time:7.77
# Target:Exp|Kernel:Uniform|sigma:0.8|eff:0.0491|Pjump:0.7213|Exx2:0.2783|rho1:0.8622|rho2:0.7575|Time:7.3
# Target:Exp|Kernel:Uniform|sigma:0.9|eff:0.0573|Pjump:0.6945|Exx2:0.3198|rho1:0.8409|rho2:0.7229|Time:8.33
# Target:Exp|Kernel:Uniform|sigma:1|eff:0.0642|Pjump:0.6692|Exx2:0.359|rho1:0.824|rho2:0.6951|Time:7.86
# Target:Exp|Kernel:Uniform|sigma:1.1|eff:0.0815|Pjump:0.6452|Exx2:0.3929|rho1:0.802|rho2:0.6581|Time:8.1
# Target:Exp|Kernel:Uniform|sigma:1.3|eff:0.1001|Pjump:0.5989|Exx2:0.4508|rho1:0.7709|rho2:0.6094|Time:7.91
# Target:Exp|Kernel:Uniform|sigma:1.5|eff:0.1159|Pjump:0.5595|Exx2:0.4993|rho1:0.7497|rho2:0.5762|Time:8.36
# Target:Exp|Kernel:Uniform|sigma:1.7|eff:0.1316|Pjump:0.5226|Exx2:0.5387|rho1:0.7347|rho2:0.5515|Time:8.08
# Target:Exp|Kernel:Uniform|sigma:1.8|eff:0.1384|Pjump:0.5071|Exx2:0.5524|rho1:0.7242|rho2:0.5356|Time:7.86
# Target:Exp|Kernel:Uniform|sigma:1.9|eff:0.1441|Pjump:0.4907|Exx2:0.5624|rho1:0.7179|rho2:0.5264|Time:7.61
# Target:Exp|Kernel:Uniform|sigma:2|eff:0.1495|Pjump:0.4748|Exx2:0.5699|rho1:0.7175|rho2:0.5236|Time:7.9
# Target:Exp|Kernel:Uniform|sigma:2.1|eff:0.1533|Pjump:0.4611|Exx2:0.5793|rho1:0.7103|rho2:0.5124|Time:7.43
# Target:Exp|Kernel:Uniform|sigma:2.2|eff:0.1592|Pjump:0.4468|Exx2:0.5849|rho1:0.7094|rho2:0.5101|Time:7.38
# Target:Exp|Kernel:Uniform|sigma:2.3|eff:0.1573|Pjump:0.4329|Exx2:0.5864|rho1:0.7087|rho2:0.5082|Time:6.91
# Target:Exp|Kernel:Uniform|sigma:2.4|eff:0.1548|Pjump:0.422|Exx2:0.5909|rho1:0.7082|rho2:0.5092|Time:7.2
# Target:Exp|Kernel:Uniform|sigma:2.5|eff:0.1584|Pjump:0.4096|Exx2:0.5929|rho1:0.7073|rho2:0.5076|Time:6.97
# Target:Exp|Kernel:Uniform|sigma:2.6|eff:0.1624|Pjump:0.3973|Exx2:0.5924|rho1:0.706|rho2:0.505|Time:6.96
# Target:Exp|Kernel:Uniform|sigma:2.8|eff:0.1569|Pjump:0.375|Exx2:0.5835|rho1:0.7076|rho2:0.5083|Time:7.19
# Target:Exp|Kernel:Uniform|sigma:3.0|eff:0.1577|Pjump:0.3555|Exx2:0.5757|rho1:0.7105|rho2:0.5103|Time:7.04
# Target:Exp|Kernel:Uniform|sigma:3.2|eff:0.1506|Pjump:0.3369|Exx2:0.5579|rho1:0.7204|rho2:0.5245|Time:7.26
# Target:Exp|Kernel:Uniform|sigma:3.5|eff:0.1436|Pjump:0.314|Exx2:0.549|rho1:0.7255|rho2:0.5355|Time:7.2
# Target:Exp|Kernel:Uniform|sigma:4|eff:0.1314|Pjump:0.2791|Exx2:0.5123|rho1:0.7444|rho2:0.5609|Time:7.3
# Target:Exp|Kernel:Uniform|sigma:4.5|eff:0.1162|Pjump:0.2511|Exx2:0.4725|rho1:0.7642|rho2:0.5922|Time:6.93
# Target:Exp|Kernel:Uniform|sigma:5|eff:0.1046|Pjump:0.2274|Exx2:0.4387|rho1:0.781|rho2:0.6168|Time:7.47
# Target:Exp|Kernel:Uniform|sigma:6|eff:0.0875|Pjump:0.192|Exx2:0.3809|rho1:0.8111|rho2:0.6653|Time:7.11
# Target:Exp|Kernel:Uniform|sigma:7|eff:0.0714|Pjump:0.1645|Exx2:0.3284|rho1:0.8367|rho2:0.7072|Time:7.36
# Target:Exp|Kernel:Uniform|sigma:8|eff:0.0656|Pjump:0.1449|Exx2:0.2879|rho1:0.8576|rho2:0.7395|Time:7.27
# Target:Exp|Kernel:TransUniform|sigma:0.1|eff:0.0346|Pjump:1.0|Exx2:0.4181|rho1:0.7916|rho2:0.7256|Time:10.59
# Target:Exp|Kernel:TransUniform|sigma:0.3|eff:0.3134|Pjump:1.0|Exx2:1.1804|rho1:0.4117|rho2:0.2624|Time:11.5
# Target:Exp|Kernel:TransUniform|sigma:0.5|eff:0.8019|Pjump:1.0|Exx2:1.8166|rho1:0.0956|rho2:0.0183|Time:11.5
# Target:Exp|Kernel:TransUniform|sigma:0.7|eff:1.2013|Pjump:1.0|Exx2:2.23|rho1:-0.1038|rho2:0.0194|Time:11.8
# Target:Exp|Kernel:TransUniform|sigma:0.8|eff:1.291|Pjump:1.0|Exx2:2.2714|rho1:-0.1402|rho2:0.0316|Time:11.83
# Target:Exp|Kernel:TransUniform|sigma:0.9|eff:1.2934|Pjump:1.0|Exx2:2.2824|rho1:-0.1384|rho2:0.028|Time:11.58
# Target:Exp|Kernel:TransUniform|sigma:1|eff:1.2324|Pjump:1.0|Exx2:2.2219|rho1:-0.1064|rho2:0.0144|Time:11.16
# Target:Exp|Kernel:TransUniform|sigma:1.1|eff:1.0962|Pjump:1.0|Exx2:2.0838|rho1:-0.0445|rho2:0.0011|Time:11.53
# Target:Exp|Kernel:TransUniform|sigma:1.3|eff:0.8383|Pjump:1.0|Exx2:1.8359|rho1:0.079|rho2:0.0083|Time:11.07
# Target:Exp|Kernel:TransUniform|sigma:1.5|eff:0.849|Pjump:1.0|Exx2:1.8484|rho1:0.0756|rho2:0.0097|Time:11.47
# Target:Exp|Kernel:TransUniform|sigma:1.7|eff:0.9758|Pjump:1.0|Exx2:1.9815|rho1:0.0114|rho2:-0.0006|Time:11.28
# Target:Exp|Kernel:TransUniform|sigma:1.8|eff:1.0593|Pjump:1.0|Exx2:2.0424|rho1:-0.0246|rho2:-0.0009|Time:11.31
# Target:Exp|Kernel:TransUniform|sigma:1.9|eff:1.1084|Pjump:1.0|Exx2:2.0948|rho1:-0.0501|rho2:0.0036|Time:11.35
# Target:Exp|Kernel:TransUniform|sigma:2|eff:1.1352|Pjump:1.0|Exx2:2.1244|rho1:-0.0619|rho2:0.0064|Time:11.8
# Target:Exp|Kernel:TransUniform|sigma:2.1|eff:1.1218|Pjump:1.0|Exx2:2.1125|rho1:-0.0584|rho2:0.0045|Time:11.53
# Target:Exp|Kernel:TransUniform|sigma:2.2|eff:1.0757|Pjump:1.0|Exx2:2.0773|rho1:-0.0379|rho2:0.0021|Time:11.15
# Target:Exp|Kernel:TransUniform|sigma:2.3|eff:1.008|Pjump:1.0|Exx2:2.0154|rho1:-0.0034|rho2:-0.0015|Time:11.54
# Target:Exp|Kernel:TransUniform|sigma:2.4|eff:0.9362|Pjump:1.0|Exx2:1.9446|rho1:0.0318|rho2:0.0001|Time:11.58
# Target:Exp|Kernel:TransUniform|sigma:2.5|eff:0.9111|Pjump:1.0|Exx2:1.9162|rho1:0.0462|rho2:0.0023|Time:11.52
# Target:Exp|Kernel:TransUniform|sigma:2.6|eff:0.9053|Pjump:1.0|Exx2:1.9042|rho1:0.0462|rho2:0.0024|Time:11.68
# Target:Exp|Kernel:TransUniform|sigma:2.8|eff:0.9487|Pjump:1.0|Exx2:1.9537|rho1:0.019|rho2:0.0018|Time:11.9
# Target:Exp|Kernel:TransUniform|sigma:3.0|eff:1.052|Pjump:1.0|Exx2:2.0531|rho1:-0.0238|rho2:-0.0001|Time:11.69
# Target:Exp|Kernel:TransUniform|sigma:3.2|eff:1.076|Pjump:1.0|Exx2:2.0806|rho1:-0.0393|rho2:0.0029|Time:11.7
# Target:Exp|Kernel:TransUniform|sigma:3.5|eff:0.9854|Pjump:1.0|Exx2:1.9833|rho1:0.0086|rho2:-0.0013|Time:11.75
# Target:Exp|Kernel:TransUniform|sigma:4|eff:0.9741|Pjump:1.0|Exx2:1.9807|rho1:0.008|rho2:-0.0005|Time:12.44
# Target:Exp|Kernel:TransUniform|sigma:4.5|eff:1.0365|Pjump:1.0|Exx2:2.0383|rho1:-0.0209|rho2:0.0011|Time:12.7
# Target:Exp|Kernel:TransUniform|sigma:5|eff:0.9673|Pjump:1.0|Exx2:1.9553|rho1:0.0193|rho2:0.0007|Time:11.67
# Target:Exp|Kernel:TransUniform|sigma:6|eff:0.9588|Pjump:1.0|Exx2:1.9523|rho1:0.0201|rho2:-0.0009|Time:11.84
# Target:Exp|Kernel:TransUniform|sigma:7|eff:0.9812|Pjump:1.0|Exx2:1.9937|rho1:0.0091|rho2:0.0005|Time:12.19
# Target:Exp|Kernel:TransUniform|sigma:8|eff:1.0255|Pjump:1.0|Exx2:2.016|rho1:-0.0074|rho2:0.0|Time:12.62
# Target:Exp|Kernel:TransBactrian|sigma:0.1|eff:0.0333|Pjump:1.0|Exx2:0.4591|rho1:0.7707|rho2:0.7325|Time:11.21
# Target:Exp|Kernel:TransBactrian|sigma:0.3|eff:0.3363|Pjump:1.0|Exx2:1.3075|rho1:0.3469|rho2:0.2816|Time:10.27
# Target:Exp|Kernel:TransBactrian|sigma:0.5|eff:0.9791|Pjump:1.0|Exx2:2.0282|rho1:-0.0141|rho2:0.0402|Time:10.9
# Target:Exp|Kernel:TransBactrian|sigma:0.7|eff:1.6913|Pjump:1.0|Exx2:2.5576|rho1:-0.2848|rho2:0.1106|Time:10.86
# Target:Exp|Kernel:TransBactrian|sigma:0.8|eff:1.9284|Pjump:1.0|Exx2:2.7205|rho1:-0.3678|rho2:0.1992|Time:11.09
# Target:Exp|Kernel:TransBactrian|sigma:0.9|eff:2.0074|Pjump:1.0|Exx2:2.8143|rho1:-0.4091|rho2:0.2599|Time:11.53
# Target:Exp|Kernel:TransBactrian|sigma:1|eff:1.9911|Pjump:1.0|Exx2:2.825|rho1:-0.4097|rho2:0.2605|Time:11.73
# Target:Exp|Kernel:TransBactrian|sigma:1.1|eff:1.9219|Pjump:1.0|Exx2:2.7379|rho1:-0.3754|rho2:0.2134|Time:11.32
# Target:Exp|Kernel:TransBactrian|sigma:1.3|eff:1.5174|Pjump:1.0|Exx2:2.4517|rho1:-0.2278|rho2:0.0754|Time:11.76
# Target:Exp|Kernel:TransBactrian|sigma:1.5|eff:1.1145|Pjump:1.0|Exx2:2.1179|rho1:-0.0559|rho2:0.0058|Time:11.82
# Target:Exp|Kernel:TransBactrian|sigma:1.7|eff:0.8768|Pjump:1.0|Exx2:1.8707|rho1:0.0638|rho2:0.0051|Time:11.64
# Target:Exp|Kernel:TransBactrian|sigma:1.8|eff:0.8377|Pjump:1.0|Exx2:1.8196|rho1:0.0902|rho2:0.0108|Time:11.87
# Target:Exp|Kernel:TransBactrian|sigma:1.9|eff:0.8197|Pjump:1.0|Exx2:1.8018|rho1:0.1|rho2:0.0141|Time:11.99
# Target:Exp|Kernel:TransBactrian|sigma:2|eff:0.8217|Pjump:1.0|Exx2:1.8067|rho1:0.0971|rho2:0.0122|Time:11.91
# Target:Exp|Kernel:TransBactrian|sigma:2.1|eff:0.8425|Pjump:1.0|Exx2:1.8312|rho1:0.0819|rho2:0.008|Time:11.71
# Target:Exp|Kernel:TransBactrian|sigma:2.2|eff:0.8799|Pjump:1.0|Exx2:1.8612|rho1:0.0639|rho2:0.0044|Time:11.67
# Target:Exp|Kernel:TransBactrian|sigma:2.3|eff:0.9272|Pjump:1.0|Exx2:1.9128|rho1:0.0441|rho2:0.0018|Time:11.98
# Target:Exp|Kernel:TransBactrian|sigma:2.4|eff:0.9473|Pjump:1.0|Exx2:1.9436|rho1:0.0269|rho2:0.0014|Time:12.16
# Target:Exp|Kernel:TransBactrian|sigma:2.5|eff:0.9787|Pjump:1.0|Exx2:1.9659|rho1:0.0118|rho2:0.0011|Time:11.68
# Target:Exp|Kernel:TransBactrian|sigma:2.6|eff:0.9878|Pjump:1.0|Exx2:1.996|rho1:0.0007|rho2:0.0025|Time:11.73
# Target:Exp|Kernel:TransBactrian|sigma:2.8|eff:1.0096|Pjump:1.0|Exx2:2.0224|rho1:-0.0085|rho2:-0.0015|Time:11.99
# Target:Exp|Kernel:TransBactrian|sigma:3.0|eff:1.0135|Pjump:1.0|Exx2:2.0149|rho1:-0.007|rho2:-0.0004|Time:11.9
# Target:Exp|Kernel:TransBactrian|sigma:3.2|eff:0.9998|Pjump:1.0|Exx2:2.0072|rho1:-0.0028|rho2:0.0004|Time:11.95
# Target:Exp|Kernel:TransBactrian|sigma:3.5|eff:1.0046|Pjump:1.0|Exx2:1.9992|rho1:0.0|rho2:-0.0021|Time:11.84
# Target:Exp|Kernel:TransBactrian|sigma:4|eff:1.0051|Pjump:1.0|Exx2:2.0035|rho1:-0.0012|rho2:-0.0015|Time:12.14
# Target:Exp|Kernel:TransBactrian|sigma:4.5|eff:1.0092|Pjump:1.0|Exx2:2.0118|rho1:-0.002|rho2:0.0006|Time:11.88
# Target:Exp|Kernel:TransBactrian|sigma:5|eff:0.9851|Pjump:1.0|Exx2:1.9946|rho1:0.0007|rho2:0.0011|Time:11.67
# Target:Exp|Kernel:TransBactrian|sigma:6|eff:0.9979|Pjump:1.0|Exx2:1.999|rho1:0.0007|rho2:-0.0002|Time:12.07
# Target:Exp|Kernel:TransBactrian|sigma:7|eff:1.0015|Pjump:1.0|Exx2:2.0065|rho1:-0.0003|rho2:-0.002|Time:12.22
# Target:Exp|Kernel:TransBactrian|sigma:8|eff:1.0027|Pjump:1.0|Exx2:1.9945|rho1:0.0006|rho2:-0.0006|Time:11.92
# Target:Exp|Kernel:TransStrawHat|sigma:0.1|eff:0.0324|Pjump:1.0|Exx2:0.4714|rho1:0.765|rho2:0.7349|Time:10.52
# Target:Exp|Kernel:TransStrawHat|sigma:0.3|eff:0.3421|Pjump:1.0|Exx2:1.3292|rho1:0.3353|rho2:0.2897|Time:10.51
# Target:Exp|Kernel:TransStrawHat|sigma:0.5|eff:1.012|Pjump:1.0|Exx2:2.0797|rho1:-0.0385|rho2:0.0561|Time:10.83
# Target:Exp|Kernel:TransStrawHat|sigma:0.7|eff:1.7811|Pjump:1.0|Exx2:2.6615|rho1:-0.326|rho2:0.1525|Time:11.01
# Target:Exp|Kernel:TransStrawHat|sigma:0.8|eff:2.0072|Pjump:1.0|Exx2:2.8367|rho1:-0.4238|rho2:0.2792|Time:11.42
# Target:Exp|Kernel:TransStrawHat|sigma:0.9|eff:2.0097|Pjump:1.0|Exx2:2.9467|rho1:-0.4704|rho2:0.3673|Time:12.19
# Target:Exp|Kernel:TransStrawHat|sigma:1|eff:2.0621|Pjump:1.0|Exx2:2.9458|rho1:-0.469|rho2:0.359|Time:12.43
# Target:Exp|Kernel:TransStrawHat|sigma:1.1|eff:2.0701|Pjump:1.0|Exx2:2.858|rho1:-0.4289|rho2:0.2813|Time:12.07
# Target:Exp|Kernel:TransStrawHat|sigma:1.3|eff:1.5913|Pjump:1.0|Exx2:2.4872|rho1:-0.2435|rho2:0.0747|Time:12.38
# Target:Exp|Kernel:TransStrawHat|sigma:1.5|eff:0.9152|Pjump:1.0|Exx2:1.9186|rho1:0.0393|rho2:0.0019|Time:13.84
# Target:Exp|Kernel:TransStrawHat|sigma:1.7|eff:0.6207|Pjump:1.0|Exx2:1.5617|rho1:0.2184|rho2:0.0612|Time:12.25
# Target:Exp|Kernel:TransStrawHat|sigma:1.8|eff:0.5803|Pjump:1.0|Exx2:1.5231|rho1:0.2369|rho2:0.0803|Time:12.1
# Target:Exp|Kernel:TransStrawHat|sigma:1.9|eff:0.6014|Pjump:1.0|Exx2:1.5521|rho1:0.2206|rho2:0.0748|Time:12.27
# Target:Exp|Kernel:TransStrawHat|sigma:2|eff:0.669|Pjump:1.0|Exx2:1.6476|rho1:0.177|rho2:0.05|Time:12.0
# Target:Exp|Kernel:TransStrawHat|sigma:2.1|eff:0.7886|Pjump:1.0|Exx2:1.7613|rho1:0.1148|rho2:0.0205|Time:11.92
# Target:Exp|Kernel:TransStrawHat|sigma:2.2|eff:0.9098|Pjump:1.0|Exx2:1.9139|rho1:0.0434|rho2:0.0047|Time:11.92
# Target:Exp|Kernel:TransStrawHat|sigma:2.3|eff:1.045|Pjump:1.0|Exx2:2.0637|rho1:-0.0273|rho2:0.0027|Time:11.68
# Target:N01_Logistic|Kernel:Uniform|sigma:2|eff:0.2697|Pjump:0.4403|Exx2:0.875|rho1:0.5624|rho2:0.3211|Time:7.85
# Target:N01_Logistic|Kernel:Uniform|sigma:2.1|eff:0.2764|Pjump:0.4233|Exx2:0.8798|rho1:0.5617|rho2:0.3188|Time:7.48
# Target:N01_Logistic|Kernel:Uniform|sigma:2.2|eff:0.2751|Pjump:0.4066|Exx2:0.8748|rho1:0.5618|rho2:0.3175|Time:7.89
# Target:N01_Logistic|Kernel:Uniform|sigma:2.3|eff:0.2716|Pjump:0.392|Exx2:0.8753|rho1:0.5622|rho2:0.3204|Time:7.57
# Target:N01_Logistic|Kernel:Uniform|sigma:2.4|eff:0.2681|Pjump:0.3776|Exx2:0.8698|rho1:0.5647|rho2:0.3222|Time:7.85
# Target:N01_Logistic|Kernel:Uniform|sigma:2.5|eff:0.2662|Pjump:0.3631|Exx2:0.8551|rho1:0.5723|rho2:0.3317|Time:7.47
# Target:N01_Logistic|Kernel:Uniform|sigma:2.6|eff:0.259|Pjump:0.3512|Exx2:0.8483|rho1:0.578|rho2:0.3377|Time:7.77
# Target:N01_Logistic|Kernel:Uniform|sigma:2.8|eff:0.2472|Pjump:0.3271|Exx2:0.8174|rho1:0.5912|rho2:0.3546|Time:7.61
# Target:N01_Logistic|Kernel:Uniform|sigma:3.0|eff:0.2315|Pjump:0.3062|Exx2:0.7841|rho1:0.6086|rho2:0.3762|Time:7.94
# Target:N01_Logistic|Kernel:Uniform|sigma:3.2|eff:0.2172|Pjump:0.2873|Exx2:0.7473|rho1:0.6272|rho2:0.4002|Time:7.64
# Target:N01_Logistic|Kernel:Uniform|sigma:3.5|eff:0.1956|Pjump:0.2621|Exx2:0.6875|rho1:0.6553|rho2:0.4358|Time:7.91
# Target:N01_Logistic|Kernel:Uniform|sigma:4|eff:0.1729|Pjump:0.2299|Exx2:0.6129|rho1:0.6926|rho2:0.4858|Time:7.58
# Target:N01_Logistic|Kernel:Uniform|sigma:4.5|eff:0.1496|Pjump:0.2045|Exx2:0.5459|rho1:0.7268|rho2:0.533|Time:7.8
# Target:N01_Logistic|Kernel:Uniform|sigma:5|eff:0.1326|Pjump:0.1843|Exx2:0.4961|rho1:0.7522|rho2:0.5703|Time:7.69
# Target:N01_Logistic|Kernel:Uniform|sigma:6|eff:0.108|Pjump:0.1534|Exx2:0.4113|rho1:0.7946|rho2:0.6349|Time:7.96
# Target:N01_Logistic|Kernel:Uniform|sigma:7|eff:0.0903|Pjump:0.1312|Exx2:0.3503|rho1:0.8253|rho2:0.6835|Time:7.66
# Target:N01_Logistic|Kernel:Uniform|sigma:8|eff:0.077|Pjump:0.1149|Exx2:0.3055|rho1:0.8474|rho2:0.7186|Time:8.1
# Target:N01_Logistic|Kernel:TransUniform|sigma:0.1|eff:0.0488|Pjump:0.8669|Exx2:0.1974|rho1:0.9011|rho2:0.8147|Time:18.66
# Target:N01_Logistic|Kernel:TransUniform|sigma:0.3|eff:0.2911|Pjump:0.693|Exx2:0.9158|rho1:0.5416|rho2:0.2961|Time:18.69
# Target:N01_Logistic|Kernel:TransUniform|sigma:0.5|eff:0.4911|Pjump:0.6691|Exx2:1.3693|rho1:0.3157|rho2:0.1141|Time:19.29
# Target:N01_Logistic|Kernel:TransUniform|sigma:0
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:2|eff:0.4564|Pjump:0.6834|Exx2:1.2911|rho1:0.3553|rho2:0.1347|Time:20.48
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:2.1|eff:0.4994|Pjump:0.6828|Exx2:1.3681|rho1:0.3176|rho2:0.1134|Time:21.0
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:2.2|eff:0.5787|Pjump:0.6947|Exx2:1.4928|rho1:0.2538|rho2:0.0723|Time:20.39
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:2.3|eff:0.7131|Pjump:0.7137|Exx2:1.6673|rho1:0.1676|rho2:0.0303|Time:20.45
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:2.4|eff:0.7584|Pjump:0.715|Exx2:1.7269|rho1:0.1356|rho2:0.0224|Time:20.64
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:2.5|eff:0.7805|Pjump:0.708|Exx2:1.7767|rho1:0.1109|rho2:0.0192|Time:20.59
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:2.6|eff:0.8048|Pjump:0.697|Exx2:1.8116|rho1:0.094|rho2:0.0177|Time:20.42
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:2.8|eff:0.7912|Pjump:0.6844|Exx2:1.7703|rho1:0.1121|rho2:0.0192|Time:20.5
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:3.0|eff:0.6431|Pjump:0.7071|Exx2:1.5843|rho1:0.2048|rho2:0.0474|Time:21.09
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:3.2|eff:0.5613|Pjump:0.7103|Exx2:1.451|rho1:0.2731|rho2:0.0796|Time:20.48
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:3.5|eff:0.5676|Pjump:0.6864|Exx2:1.469|rho1:0.2654|rho2:0.0773|Time:20.72
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:4|eff:0.708|Pjump:0.7048|Exx2:1.6812|rho1:0.1603|rho2:0.0337|Time:20.95
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:4.5|eff:0.6215|Pjump:0.7049|Exx2:1.553|rho1:0.2219|rho2:0.0573|Time:20.86
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:5|eff:0.5989|Pjump:0.6916|Exx2:1.5268|rho1:0.2358|rho2:0.0633|Time:20.7
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:6|eff:0.6152|Pjump:0.7054|Exx2:1.5395|rho1:0.2306|rho2:0.059|Time:20.48
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:7|eff:0.6983|Pjump:0.7012|Exx2:1.6655|rho1:0.1667|rho2:0.0358|Time:20.81
# Target:N01_Logistic|Kernel:TransStrawHat|sigma:8|eff:0.5999|Pjump:0.6941|Exx2:1.5472|rho1:0.2277|rho2:0.0579|Time:20.58
# 总共用时: 5226.292528

# %%
np.save('table6',target_result)

# %%
name = ['Kernel' ,'Sigma', 'Eff', 'Pjump', 'Exx2', 'rho1', 'rho2']
print('{:<25} {:<8} {:<8} {:<8} {:<8} {:<8} {:<8}'.format(*name))

for target in targetset:
    kernel_info = {}
    print('                                      ',target)
    for kernel in kernelset:
        index = [np.argmax(target_result[target][0][i]) for i in kernelset]
        index_need = index[np.where(np.array(kernelset)==kernel)[0][0]]
        info = [target_result[target][i][kernel][index_need] for i in range(len(target_result[target])-1)]
        rho1 = info[3][0]; rho2 = info[3][1]
        kernel_info[kernel] = np.round(np.concatenate([[sigmaset[index_need]],info[0:3],[rho1,rho2]]),3)
        kernel_info[kernel] = kernel_info[kernel].tolist()
        kernel_info[kernel].insert(0,kernel)
        print('{:<25} {:<8} {:<8} {:<8} {:<8} {:<8} {:<8}'.format(*kernel_info[kernel]))
# Out:
# Kernel                    Sigma    Eff      Pjump    Exx2     rho1     rho2
#                                        Exp
# Uniform                   2.6      0.162    0.397    0.592    0.706    0.505
# TransUniform              0.9      1.293    1.0      2.282    -0.138   0.028
# TransBactrian             0.9      2.007    1.0      2.814    -0.409   0.26
# TransStrawHat             1.1      2.07     1.0      2.858    -0.429   0.281
#                                        Folded_Gaussian
# Uniform                   1.5      0.277    0.544    0.327    0.549    0.306
# TransUniform              0.8      1.072    0.839    0.757    -0.038   0.002
# TransBactrian             1.0      1.924    0.837    0.962    -0.324   0.11
# TransStrawHat             1.0      2.212    0.843    1.01     -0.388   0.161
#                                        N01_Logistic
# Uniform                   2.1      0.276    0.423    0.88     0.562    0.319
# TransUniform              0.8      0.828    0.712    1.826    0.089    0.013
# TransBactrian             1.0      1.35     0.726    2.291    -0.148   0.026
# TransStrawHat             0.9      1.538    0.764    2.435    -0.216   0.049

# %% [markdown]
# ### The plot below is the probability density of  target after transformed:

# %%
from IPython.display import HTML
from IPython.display import display

# Taken from https://stackoverflow.com/questions/31517194/how-to-hide-one-specific-cell-input-or-output-in-ipython-notebook
tag = HTML('''<script>
code_show=true; 
function code_toggle() {
    if (code_show){
        $('div.cell.code_cell.rendered.selected div.input').hide();
    } else {
        $('div.cell.code_cell.rendered.selected div.input').show();
    }
    code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
To show/hide this cell's raw code input, click <a href="javascript:code_toggle()">here</a>.''')
display(tag)

############### Write code below ##################

from matplotlib.pyplot import figure
figure(num=None, figsize=(12,9), dpi=80, facecolor='w', edgecolor='k')

ori = np.random.exponential(size=1000000,scale=1.0)
trans = np.exp(-ori)
xindex = np.arange(0.001,0.999,0.001)
yindex = np.ones(len(xindex))
plt.subplot(221)
plt.hist(trans, bins=100, density=True)
plt.plot(xindex,yindex)
plt.gca().set_title('$N(0,1)$ target \n after transformed with Exp(1)-CDF')

ori = abs(np.random.normal(size=1000000))
trans = np.exp(-ori)
xindex = np.arange(0.001,0.999,0.001)
inverse = np.array([exp_inverse(i) for i in xindex])
diff_term = np.array([exp_diff(i) for i in xindex])
yindex = 2*scipy.stats.norm.pdf(inverse) * diff_term
plt.subplot(222)
plt.hist(trans, bins=100, density=True)
plt.plot(xindex,yindex)
plt.gca().set_title('$N_+(0,1)$ target \n after transformed with Exp(1)-CDF')


ori = np.random.normal(size=1000000)
trans = scipy.stats.t.cdf(x=ori,df=2)
xindex = np.arange(0.001,0.999,0.001)
inverse = np.array([t_inverse(i) for i in xindex])
diff_term = np.array([t_diff(i) for i in xindex])
yindex = scipy.stats.norm.pdf(inverse) * diff_term
plt.subplot(223)
plt.hist(trans, bins=100, density=True)
plt.plot(xindex,yindex)
plt.gca().set_title('$N(0,1)$ target \n after transformed with t2-CDF')

ori = np.random.normal(size=1000000)
trans = scipy.stats.logistic.cdf(x=ori)
xindex = np.arange(0.001,0.999,0.001)
inverse = np.array([logistic_inverse(i) for i in xindex])
diff_term = np.array([logistic_diff(i) for i in xindex])
yindex = scipy.stats.norm.pdf(inverse) * diff_term
plt.subplot(224)
plt.hist(trans, bins=100, density=True)
plt.plot(xindex,yindex)
plt.gca().set_title('$N(0,1)$ target \n after transformed with logistic-CDF')

plt.show()
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#     if (code_show){
#         $('div.cell.code_cell.rendered.selected div.input').hide();
#     } else {
#         $('div.cell.code_cell.rendered.selected div.input').show();
#     }
#     code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To show/hide this cell's raw code input, click <a href="javascript:code_toggle()">here</a>.
